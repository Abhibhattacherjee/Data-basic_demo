# %% [markdown]
# IMPORTED  LIB

# %%
import pandas  as  pd
import os
os.getcwd()     #  Here  we  have  imported   the  neccessary  lib    for   analysis  
import matplotlib. pyplot as plt

# %%
dataset= pd.read_excel(r"C:\Program Files\uber_deliveryServiceDataset.xlsx")

# %%
dataset    #  here  we  have  imported   the  dataset  with  ref  variable   dataset  in  the  pandas  lib
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0      79.0       55.0         42.63         20.43  5.51
# 1         NaT  12.0      73.0       41.0         36.43         15.53  5.48
# 2         NaT  13.0      54.0       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0     193.0      170.0         64.20         31.47  5.31
# 4         NaT  12.0     258.0      210.0         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT  12.0     378.0      306.0         99.07         52.02  5.75
# 86        NaT  13.0     321.0      149.0         76.90         30.55  5.86
# 87 2013-09-30  11.0     180.0      151.0         68.33         24.87  5.21
# 88        NaT  12.0     307.0      247.0         78.25         45.78  5.75
# 89        NaT  13.0     215.0      275.0         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %% [markdown]
# CUTTING   DOWN  AND  CHECKING THE   DATA TYPE  AVALIABLE  IN   THE  DATASET

# %%
dataset.head()    #  so  we  need  only  50 data elements  for  the  analysis  so  50*20=1000 boxes  data
# Out:
#         Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0 2013-09-01  11.0      79.0       55.0         42.63         20.43  5.51
# 1        NaT  12.0      73.0       41.0         36.43         15.53  5.48
# 2        NaT  13.0      54.0       50.0         23.02         17.76  5.07
# 3 2013-09-02  11.0     193.0      170.0         64.20         31.47  5.31
# 4        NaT  12.0     258.0      210.0         80.28         38.68  4.94
#
#    aETA  Delivered Products  Total Products Available
# 0  7.19               103.0                     159.0
# 1  8.48                 4.0                       8.0
# 2  8.94                 5.0                       9.0
# 3  6.55               288.0                     414.0
# 4  6.08                 7.0                      65.0

# %%
dataset =dataset.rename(columns={'Completes':'completed trip', })
print(dataset)   #  so now     we have  changd  the  column name
# Out:
#          Date  Hour  Requests  completed trip  Supply Hours  Time On Trip  \
# 0  2013-09-01  11.0      79.0            55.0         42.63         20.43
# 1         NaT  12.0      73.0            41.0         36.43         15.53
# 2         NaT  13.0      54.0            50.0         23.02         17.76
# 3  2013-09-02  11.0     193.0           170.0         64.20         31.47
# 4         NaT  12.0     258.0           210.0         80.28         38.68
# ..        ...   ...       ...             ...           ...           ...
# 85        NaT  12.0     378.0           306.0         99.07         52.02
# 86        NaT  13.0     321.0           149.0         76.90         30.55
# 87 2013-09-30  11.0     180.0           151.0         68.33         24.87
# 88        NaT  12.0     307.0           247.0         78.25         45.78
# 89        NaT  13.0     215.0           275.0         56.83         29.13
#
#     pETA  aETA  Delivered Products  Total Products Available
# ...

# %%
df=dataset   #  here   we  have assigned  the  val of  dataset  to the  ref varibale   df

# %%
df
# Out:
#          Date  Hour  Requests  completed trip  Supply Hours  Time On Trip  \
# 0  2013-09-01  11.0      79.0            55.0         42.63         20.43
# 1         NaT  12.0      73.0            41.0         36.43         15.53
# 2         NaT  13.0      54.0            50.0         23.02         17.76
# 3  2013-09-02  11.0     193.0           170.0         64.20         31.47
# 4         NaT  12.0     258.0           210.0         80.28         38.68
# ..        ...   ...       ...             ...           ...           ...
# 85        NaT  12.0     378.0           306.0         99.07         52.02
# 86        NaT  13.0     321.0           149.0         76.90         30.55
# 87 2013-09-30  11.0     180.0           151.0         68.33         24.87
# 88        NaT  12.0     307.0           247.0         78.25         45.78
# 89        NaT  13.0     215.0           275.0         56.83         29.13
#
#     pETA  aETA  Delivered Products  Total Products Available
# ...

# %%
# taking  some  more  relevant   data 
import os
df1 = pd.read_csv(r'C:\Program Files\uber-2016.csv')
print(df1)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
print(type(df['Date'][0]))  #   no  need   to  cgange   the  datetype  as  is  already   datetime  datatype
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
import numpy  as  np 
df=pd.read_excel(r'C:\Program Files\uber_deliveryServiceDataset.xlsx', dtype={'Requests':np.int64})
print(df.dtypes)
df#   changing   the  values   to int  val  in the   Request   column.
# Out:
# Date                        datetime64[ns]
# Hour                               float64
# Requests                             int64
# Completes                          float64
# Supply Hours                       float64
# Time On Trip                       float64
# pETA                               float64
# aETA                               float64
# Delivered Products                 float64
# Total Products Available           float64
# dtype: object
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0        79       55.0         42.63         20.43  5.51
# 1         NaT  12.0        73       41.0         36.43         15.53  5.48
# 2         NaT  13.0        54       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0       193      170.0         64.20         31.47  5.31
# 4         NaT  12.0       258      210.0         80.28         38.68  4.94
# ...

# %%
import requests
import json
response_API = requests.get('https://gmail.googleapis.com/$discovery/rest?version=v1')
#print(response_API.status_code)
data = response_API.text   # this   helps    to  print  a  format  into  a txt   format using  json
parse_json = json.loads(data)
info = parse_json['description']
print("Info about API:\n", info)
key = parse_json['parameters']['key']['description']
print("\nDescription about the key:\n",key)



#   here  we  have  imporsted   some   data   by  using   the  Web Api   using  a  gmail  data  api   in json  format
# Out:
# Info about API:
#  The Gmail API lets you view and manage Gmail mailbox data like threads, messages, and labels.
#
# Description about the key:
#  API key. Your API key identifies your project and provides you with API access, quota, and reports. Required unless you provide an OAuth 2.0 token.

# %%
import requests
import json
response_API = requests.get('https://api.covid19india.org/state_district_wise.json')
#print(response_API.status_code)
data = response_API.text
parse_json = json.loads(data)
active_case = parse_json['Andaman and Nicobar Islands']['districtData']['South Andaman']['active']
print("Active cases in South Andaman:", active_case)
print("Andaman and Nicobar Islands:", active_case)
print('districtData:',active_case)



#   here   we   have  some   data   pulled    from  covid  india .api as   to  see  that  the , active cases  in  south  anadaman 
#   has  19  active   cases    which  may  affect   the   above  request   for  such  state
# Out:
# Active cases in South Andaman: 19
# Andaman and Nicobar Islands: 19
# districtData: 19

# %%
df1= pd.read_csv(r'C:\Program Files\uber-2016.csv')
df1.head(50)



#   here  we need  only   50  values   here   so  we  are  checking   only   50  values  in  2016  data set
# Out:
#         START_DATE*        END_DATE* CATEGORY*               START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business          Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business          Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business          Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business          Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business          Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business      West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business      West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business                 Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business                 Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business              Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business             New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business             Elmhurst
# 12  1/10/2016 19:12  1/10/2016 19:32  Business              Midtown
# ...

# %%
df1.loc[:,['START_DATE*','MILES*','PURPOSE*']]   #  AS  we  only  wan t o  check  through  these  data   so  data  sclicing  is   done  here
# Out:
#            START_DATE*   MILES*         PURPOSE*
# 0       1/1/2016 21:11      5.1   Meal/Entertain
# 1        1/2/2016 1:25      5.0              NaN
# 2       1/2/2016 20:25      4.8  Errand/Supplies
# 3       1/5/2016 17:31      4.7          Meeting
# 4       1/6/2016 14:42     63.7   Customer Visit
# ...                ...      ...              ...
# 1151  12/31/2016 13:24      3.9   Temporary Site
# 1152  12/31/2016 15:03     16.2          Meeting
# 1153  12/31/2016 21:32      6.4   Temporary Site
# 1154  12/31/2016 22:08     48.2   Temporary Site
# 1155            Totals  12204.7              NaN
#
# [1156 rows x 3 columns]

# %%
df1['MILES*'].count()  #  so   here  we  have  counted   the  total   miles   covered  from  the   dataset  2
# Out:
# 1156

# %%
df
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0        79       55.0         42.63         20.43  5.51
# 1         NaT  12.0        73       41.0         36.43         15.53  5.48
# 2         NaT  13.0        54       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0       193      170.0         64.20         31.47  5.31
# 4         NaT  12.0       258      210.0         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT  12.0       378      306.0         99.07         52.02  5.75
# 86        NaT  13.0       321      149.0         76.90         30.55  5.86
# 87 2013-09-30  11.0       180      151.0         68.33         24.87  5.21
# 88        NaT  12.0       307      247.0         78.25         45.78  5.75
# 89        NaT  13.0       215      275.0         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %%
df['Completes'].count()  #   so   here  we  can see  that  the   total  trip   completd   is  90
# Out:
# 90

# %%
df['Completes'].unique()  #  it  is  shows   how  many  numbers  insdie   this  completed  trip  are  unique
# Out:
# array([ 55.,  41.,  50., 170., 210., 107.,  34.,  15.,  43.,  39.,  20.,
#        167., 256., 109., 151., 222., 101., 298., 396., 340., 164., 257.,
#        100., 155., 187., 120.,  44.,  38.,  12.,  76., 232., 128., 166.,
#         60., 250., 284., 123., 186., 267., 121., 136.,  91.,  37.,  35.,
#         56.,  28.,  27., 268., 161., 218., 260.,  71., 266., 420., 156.,
#        269., 376., 215., 183., 130.,  33.,  18.,   6.,  68.,  52., 300.,
#        296., 361., 140., 240., 306., 149., 247., 275.])

# %%
df1['MILES*'].unique() #  for   the  2nd  dataset
# Out:
# array([5.10000e+00, 5.00000e+00, 4.80000e+00, 4.70000e+00, 6.37000e+01,
#        4.30000e+00, 7.10000e+00, 8.00000e-01, 8.30000e+00, 1.65000e+01,
#        1.08000e+01, 7.50000e+00, 6.20000e+00, 6.40000e+00, 1.60000e+00,
#        1.70000e+00, 1.90000e+00, 4.00000e+00, 1.80000e+00, 2.40000e+00,
#        2.00000e+00, 1.51000e+01, 1.12000e+01, 1.18000e+01, 2.19000e+01,
#        3.90000e+00, 8.00000e+00, 1.04000e+01, 7.20000e+00, 7.60000e+00,
#        1.71000e+01, 4.02000e+01, 1.00000e+00, 2.30000e+00, 1.40000e+00,
#        5.00000e-01, 1.87000e+01, 3.40000e+00, 2.70000e+00, 1.29000e+01,
#        1.90000e+01, 1.47000e+01, 1.57000e+01, 4.60000e+00, 5.20000e+00,
#        1.01000e+01, 5.80000e+00, 5.50000e+00, 5.70000e+00, 1.94000e+01,
#        2.33000e+01, 6.00000e+00, 9.70000e+00, 1.10000e+00, 9.00000e+00,
#        7.70000e+00, 1.14000e+01, 3.20000e+00, 5.60000e+00, 6.10000e+00,
#        5.30000e+00, 3.00000e+00, 1.50000e+00, 1.73000e+01, 1.35000e+01,
# ...

# %%
df['Completes'].nunique()   #  means 74  values  have  a unique   data  means  we have   74   diffrent  type   of  vals
# Out:
# 74

# %%
df1['MILES*'].nunique()  #  so Miles  covered   have   totol   257  diffrent    type   of values in it
# Out:
# 257

# %%
print(df['Completes'].describe())    #   here  it   tell  neccessary stats   which  we can need
# Out:
# count     90.000000
# mean     149.833333
# std      105.484889
# min        6.000000
# 25%       50.000000
# 50%      138.000000
# 75%      238.000000
# max      420.000000
# Name: Completes, dtype: float64

# %%
print(df1['MILES*'].describe())


#  if  we  want  to  see  everything   then we  have z  to  write  include all after  describe   inside  the  bracket
# Out:
# count     1156.000000
# mean        21.115398
# std        359.299007
# min          0.500000
# 25%          2.900000
# 50%          6.000000
# 75%         10.400000
# max      12204.700000
# Name: MILES*, dtype: float64

# %% [markdown]
# NOW  DROPPING A ROW  AND  COLUMNS  IN PANDAS

# %%
df
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0        79       55.0         42.63         20.43  5.51
# 1         NaT  12.0        73       41.0         36.43         15.53  5.48
# 2         NaT  13.0        54       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0       193      170.0         64.20         31.47  5.31
# 4         NaT  12.0       258      210.0         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT  12.0       378      306.0         99.07         52.02  5.75
# 86        NaT  13.0       321      149.0         76.90         30.55  5.86
# 87 2013-09-30  11.0       180      151.0         68.33         24.87  5.21
# 88        NaT  12.0       307      247.0         78.25         45.78  5.75
# 89        NaT  13.0       215      275.0         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %%
df2=df1.drop([14,45,16], axis =0)
df2                         #  so   here  we   have  successfully   drop   the  row   elements   given in te  above  list
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df2 =df1.drop(['PURPOSE*'], axis =1)
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*
# 0          Fort Pierce      5.1
# 1          Fort Pierce      5.0
# 2          Fort Pierce      4.8
# ...

# %%
df1.drop(['PURPOSE*','STOP*'], axis=1,inplace=True)
df1          #  so  we  removed   the  2  columns   from  the   dateset  permanently.
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*   MILES*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce      5.1
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce      5.0
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce      4.8
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce      4.7
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce     63.7
# ...                ...               ...       ...               ...      ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi      3.9
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location     16.2
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake      6.4
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha     48.2
# 1155            Totals               NaN       NaN               NaN  12204.7
#
# [1156 rows x 5 columns]

# %% [markdown]
# DATA MUNGING or DATA WRANGLING
#
# data munging is  the  process of changing  any file  type  to another   file   type  like html  to csv or vice  versa

# %%
# visualization of  miles  covered  in  df2 using  a boxplot
df2=df1
df2=pd.DataFrame(df1,columns=['MILES*'])
df2
df2.plot.area(stacked=True)

#  so  here we made  area   plot  of   miles  from  our  seconadry  foreign   data
# Out:
# <AxesSubplot:>

# %%
orgdata=pd.DataFrame(df, columns=['Requests','Completes','Time On Trip','Delivered Products','Total Products Available'])
orgdata
orgdata.plot.box()

#  here  we  made  a box plot   from our main source  data   of  Uber
# Out:
# <AxesSubplot:>

# %%
orgdata=pd.DataFrame(df, columns=['Supply Hours'])
orgdata
orgdata.plot.area(stacked=True)

#  here  we  made another  area plot   to  see  the  supply hours   from main  dataset
# Out:
# <AxesSubplot:>

# %% [markdown]
# USING   OF  PANDAS  DATETIME  FUNCTIONS

# %%
import  pandas  as pd
orgdata=pd.read_excel(r'C:\Program Files\uber_deliveryServiceDataset.xlsx')
orgdata
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0      79.0       55.0         42.63         20.43  5.51
# 1         NaT  12.0      73.0       41.0         36.43         15.53  5.48
# 2         NaT  13.0      54.0       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0     193.0      170.0         64.20         31.47  5.31
# 4         NaT  12.0     258.0      210.0         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT  12.0     378.0      306.0         99.07         52.02  5.75
# 86        NaT  13.0     321.0      149.0         76.90         30.55  5.86
# 87 2013-09-30  11.0     180.0      151.0         68.33         24.87  5.21
# 88        NaT  12.0     307.0      247.0         78.25         45.78  5.75
# 89        NaT  13.0     215.0      275.0         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %%
d=pd.to_datetime({'year':[2021],'month':[2],'day':[10]})
d

#  so  this  is  the  datetime  data  type  inside  pandas
# Out:
# 0   2021-02-10
# dtype: datetime64[ns]

# %% [markdown]
# inside   pandas datetime  func

# %%
df['Date']=pd.to_datetime(df['Date'])
df

#  now  we  have  changed   the  date   to datetime datatype
# Out:
#          Date  Hour  Requests  Completes  Supply Hours  Time On Trip  pETA  \
# 0  2013-09-01  11.0        79       55.0         42.63         20.43  5.51
# 1         NaT  12.0        73       41.0         36.43         15.53  5.48
# 2         NaT  13.0        54       50.0         23.02         17.76  5.07
# 3  2013-09-02  11.0       193      170.0         64.20         31.47  5.31
# 4         NaT  12.0       258      210.0         80.28         38.68  4.94
# ..        ...   ...       ...        ...           ...           ...   ...
# 85        NaT  12.0       378      306.0         99.07         52.02  5.75
# 86        NaT  13.0       321      149.0         76.90         30.55  5.86
# 87 2013-09-30  11.0       180      151.0         68.33         24.87  5.21
# 88        NaT  12.0       307      247.0         78.25         45.78  5.75
# 89        NaT  13.0       215      275.0         56.83         29.13  5.35
#
#     aETA  Delivered Products  Total Products Available
# ...

# %% [markdown]
# PANDAS  DATE RANGE  FUNC
#
# it  can change  the  style   of  the  date  format

# %%
df= pd.date_range(start='01/09/2013', end='02/09/2013', freq='D')
df

#  so it   shows  the   date   ranges  from   the   given points
# Out:
# DatetimeIndex(['2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01',
#                '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09'],
#               dtype='datetime64[ns]', freq='D')

# %%
df =pd.date_range(start='01/09/2013',end='04/09/2013', freq='M')
df

#  it  shows  the  middle   month avaiable
# Out:
# DatetimeIndex(['2013-01-31', '2013-02-28', '2013-03-31'], dtype='datetime64[ns]', freq='M')

# %%
#  to  print  current  datetime
import  datetime
dt=datetime.datetime.now()
print(dt)
# Out:
# 2022-02-23 11:57:36.328904

# %%
#  with the  current  datetime   if  we want  to see  the  , date  time  10  days  after  
print(dt+pd.to_timedelta(15,unit='D'))
# Out:
# 2022-03-10 11:57:36.328904

# %%
#  adding  date, time , month  and  year  as  a   diffrent  column
df['Day']=df['Date'].dt.day
df['Month']=df['Date'].dt.month
df['Year']=df['Date'].dt.Year
print(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3912/3949310212.py in <module>
#       1 #  adding  date, time , month  and  year  as  a   diffrent  column
# ----> 2 df['Day']=df['Date'].dt.day
#       3 df['Month']=df['Date'].dt.month
#       4 df['Year']=df['Date'].dt.Year
#       5 print(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\extension.py in __getitem__(self, key)
#     277
#     278     def __getitem__(self, key):
# --> 279         result = self._data[key]
#     280         if isinstance(result, type(self._data)):
#     281             if result.ndim == 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py in __getitem__(self, key)
#     320         only handle list-likes, slices, and integer scalars
#     321         """
# --> 322         result = super().__getitem__(key)
# ...
