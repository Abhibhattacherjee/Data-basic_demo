# %% [markdown]
# ![call_center.png](attachment:call_center.png)
#                                                                                        call  center Data

# %% [markdown]
# importing all  the  neccessary libs for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')   #  This  is imported  to  remove warning  txts

# %% [markdown]
# This is  the  january call log of  29 customers among  various  users

# %%
# importing  the  call center  dataset  inside  pandas 
df = pd.read_csv('callcenter_data.csv')
df
# Out:
#    operator inout_travelling network_type  rating   calldrop_category  \
# 0      BSNL           Indoor           3G       3        Satisfactory
# 1      BSNL           Indoor           2G       3  Poor Voice Quality
# 2      BSNL           Indoor           2G       3        Satisfactory
# 3      BSNL           Indoor           3G       3        Satisfactory
# 4      RJio          Outdoor           4G       4        Satisfactory
# 5      RJio          Outdoor           4G       4        Satisfactory
# 6      RJio          Outdoor           4G       4        Satisfactory
# 7      RJio           Indoor           4G       4        Satisfactory
# 8      RJio          Outdoor           4G       4        Satisfactory
# 9      RJio           Indoor           4G       4        Satisfactory
# 10     RJio           Indoor           4G       4        Satisfactory
# 11     BSNL          Outdoor           3G       1        Call Dropped
# ...

# %% [markdown]
# Checking  any Null Values  are  present  in  the  Dataset  or  not

# %%
df.isnull()  #  therefore  no null  values  are  there  in  this  imported  Dataset
# Out:
#     operator  inout_travelling  network_type  rating  calldrop_category  \
# 0      False             False         False   False              False
# 1      False             False         False   False              False
# 2      False             False         False   False              False
# 3      False             False         False   False              False
# 4      False             False         False   False              False
# 5      False             False         False   False              False
# 6      False             False         False   False              False
# 7      False             False         False   False              False
# 8      False             False         False   False              False
# 9      False             False         False   False              False
# 10     False             False         False   False              False
# 11     False             False         False   False              False
# ...

# %% [markdown]
# inserting  a new  column  Dates   in the  dataset

# %%
# using  the  unsert method  to insert  a  new   col
date = ['1-1-22','2-1-22','3-1-22','4-1-22','5-1-22','6-1-22','7-1-22','8-1-22','9-1-22','10-1-22','11-1-22','12-1-22','13-1-22','14-1-22','15-1-22','16-1-22','17-1-22','18-1-22','19-1-22','20-1-22','21-1-22','22-1-22','23-1--22','24-1-22','25-1-22','26-1-22','27-1-22','28-1-22','29-1-22','30-1-22']
df['date']= date

# %%
df
# Out:
#    operator inout_travelling network_type  rating   calldrop_category  \
# 0      BSNL           Indoor           3G       3        Satisfactory
# 1      BSNL           Indoor           2G       3  Poor Voice Quality
# 2      BSNL           Indoor           2G       3        Satisfactory
# 3      BSNL           Indoor           3G       3        Satisfactory
# 4      RJio          Outdoor           4G       4        Satisfactory
# 5      RJio          Outdoor           4G       4        Satisfactory
# 6      RJio          Outdoor           4G       4        Satisfactory
# 7      RJio           Indoor           4G       4        Satisfactory
# 8      RJio          Outdoor           4G       4        Satisfactory
# 9      RJio           Indoor           4G       4        Satisfactory
# 10     RJio           Indoor           4G       4        Satisfactory
# 11     BSNL          Outdoor           3G       1        Call Dropped
# ...

# %% [markdown]
# now  changing  the  dates   to  pandas datetime  datatype

# %%
import datetime
df['date']=pd.DataFrame(df['date'])
df
# changed  the  date to  datetype  format
# Out:
#    operator inout_travelling network_type  rating   calldrop_category  \
# 0      BSNL           Indoor           3G       3        Satisfactory
# 1      BSNL           Indoor           2G       3  Poor Voice Quality
# 2      BSNL           Indoor           2G       3        Satisfactory
# 3      BSNL           Indoor           3G       3        Satisfactory
# 4      RJio          Outdoor           4G       4        Satisfactory
# 5      RJio          Outdoor           4G       4        Satisfactory
# 6      RJio          Outdoor           4G       4        Satisfactory
# 7      RJio           Indoor           4G       4        Satisfactory
# 8      RJio          Outdoor           4G       4        Satisfactory
# 9      RJio           Indoor           4G       4        Satisfactory
# 10     RJio           Indoor           4G       4        Satisfactory
# 11     BSNL          Outdoor           3G       1        Call Dropped
# ...

# %% [markdown]
# here  we  have  set  the  dates col as index

# %%
print(type(df['date'][0]))

# asetting  the  date  as  Index 
df.set_index('date',inplace=True)
df
# Out:
# <class 'str'>
#          operator inout_travelling network_type  rating   calldrop_category  \
# date
# 1-1-22       BSNL           Indoor           3G       3        Satisfactory
# 2-1-22       BSNL           Indoor           2G       3  Poor Voice Quality
# 3-1-22       BSNL           Indoor           2G       3        Satisfactory
# 4-1-22       BSNL           Indoor           3G       3        Satisfactory
# 5-1-22       RJio          Outdoor           4G       4        Satisfactory
# 6-1-22       RJio          Outdoor           4G       4        Satisfactory
# 7-1-22       RJio          Outdoor           4G       4        Satisfactory
# 8-1-22       RJio           Indoor           4G       4        Satisfactory
# 9-1-22       RJio          Outdoor           4G       4        Satisfactory
# 10-1-22      RJio           Indoor           4G       4        Satisfactory
# 11-1-22      RJio           Indoor           4G       4        Satisfactory
# ...

# %% [markdown]
# dropping some columns which are useless for analysis

# %%
df.drop(['latitude','longitude'],axis =1, inplace =True)
df
#  so we  have  removed  useless cols  - latititude  and  longitude here   to make   the  data  claener  for   visualization and  analysis
# Out:
#          operator inout_travelling network_type  rating   calldrop_category  \
# date
# 1-1-22       BSNL           Indoor           3G       3        Satisfactory
# 2-1-22       BSNL           Indoor           2G       3  Poor Voice Quality
# 3-1-22       BSNL           Indoor           2G       3        Satisfactory
# 4-1-22       BSNL           Indoor           3G       3        Satisfactory
# 5-1-22       RJio          Outdoor           4G       4        Satisfactory
# 6-1-22       RJio          Outdoor           4G       4        Satisfactory
# 7-1-22       RJio          Outdoor           4G       4        Satisfactory
# 8-1-22       RJio           Indoor           4G       4        Satisfactory
# 9-1-22       RJio          Outdoor           4G       4        Satisfactory
# 10-1-22      RJio           Indoor           4G       4        Satisfactory
# 11-1-22      RJio           Indoor           4G       4        Satisfactory
# ...

# %% [markdown]
# checking   the  total  counts of  dates

# %%
df['operator'].count()

# so  there are total  30 operators  count   in operators  column
# Out:
# 30

# %%
df.head()
# Out:
#        operator inout_travelling network_type  rating   calldrop_category  \
# date
# 1-1-22     BSNL           Indoor           3G       3        Satisfactory
# 2-1-22     BSNL           Indoor           2G       3  Poor Voice Quality
# 3-1-22     BSNL           Indoor           2G       3        Satisfactory
# 4-1-22     BSNL           Indoor           3G       3        Satisfactory
# 5-1-22     RJio          Outdoor           4G       4        Satisfactory
#
#          state_name
# date
# 1-1-22          NA
# 2-1-22          NA
# 3-1-22          NA
# 4-1-22          NA
# 5-1-22  Maharashtra

# %% [markdown]
#  in operator  which  have 4 unique data named Airtel, Vi,Rjio,Bsnl
# in  inout_travelling  col we  have 2 unique number  of data named indoor and outdoor
# in network_type  we  have  3 network  type named as 2G , 3G,4G.
# in rating  we  have a  range  from (1-5)=5
# in call_drop category we  have 3 diffrent  feeds by customers- Satisfactory,Poorvoice quality,Call Dropped.
# in state_name we  have 1  state named  as -{Maharashtra} as letter  are  ommited that's  why its showing -(2)
# `

# %%
df.nunique()
# here  we  are   checking   the  count  of   total  unique  values  in each  col of   the  dataset
# Out:
# operator             4
# inout_travelling     2
# network_type         3
# rating               5
# calldrop_category    3
# state_name           2
# dtype: int64

# %%
df['operator'].unique()

#  total 4  operators
# Out:
# array(['BSNL', 'RJio', 'VI', 'Airtel'], dtype=object)

# %%
df['inout_travelling'].unique()

# total  2 feeds
# Out:
# array(['Indoor', 'Outdoor'], dtype=object)

# %%
df.describe(include='all')
# Out:
#        operator inout_travelling network_type     rating calldrop_category  \
# count        30               30           30  30.000000                30
# unique        4                2            3        NaN                 3
# top        RJio           Indoor           4G        NaN      Satisfactory
# freq         11               22           25        NaN                14
# mean        NaN              NaN          NaN   2.366667               NaN
# std         NaN              NaN          NaN   1.401559               NaN
# min         NaN              NaN          NaN   1.000000               NaN
# 25%         NaN              NaN          NaN   1.000000               NaN
# 50%         NaN              NaN          NaN   2.500000               NaN
# 75%         NaN              NaN          NaN   4.000000               NaN
# max         NaN              NaN          NaN   5.000000               NaN
#
#        state_name
# count          30
# unique          2
# ...

# %% [markdown]
# The  mean of  the  customer  rating   is  2.36
# The std .deviation of customer rating is =1
# The frequency of operator  and  the ,inout_travelling is = 11,22

# %% [markdown]
# using  the pandas alike  sql methods   to check  the  state name which  are  not NA

# %%
df[df['state_name']=='Maharashtra']
# Out:
#         operator inout_travelling network_type  rating calldrop_category  \
# date
# 5-1-22      RJio          Outdoor           4G       4      Satisfactory
# 6-1-22      RJio          Outdoor           4G       4      Satisfactory
# 7-1-22      RJio          Outdoor           4G       4      Satisfactory
# 8-1-22      RJio           Indoor           4G       4      Satisfactory
# 9-1-22      RJio          Outdoor           4G       4      Satisfactory
# 10-1-22     RJio           Indoor           4G       4      Satisfactory
# 11-1-22     RJio           Indoor           4G       4      Satisfactory
# 12-1-22     BSNL          Outdoor           3G       1      Call Dropped
# 13-1-22     RJio          Outdoor           4G       5      Satisfactory
# 14-1-22     RJio          Outdoor           4G       4      Satisfactory
# 15-1-22     RJio          Outdoor           4G       3      Satisfactory
#
#           state_name
# date
# 5-1-22   Maharashtra
# 6-1-22   Maharashtra
# ...

# %% [markdown]
# So from the  whole dataset  we  have almost  11 customers  from  Maharashtra &19 customers states data  is Not avaliable with us

# %%
sns .countplot(df['state_name'])
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='count'>

# %% [markdown]
# To see  how  many  customers   have  a  report  of Satisfactory  feedback

# %%
df[(df['calldrop_category']=='Satisfactory')|(df['operator']=='Rjio')]
# Out:
#         operator inout_travelling network_type  rating calldrop_category  \
# date
# 1-1-22      BSNL           Indoor           3G       3      Satisfactory
# 3-1-22      BSNL           Indoor           2G       3      Satisfactory
# 4-1-22      BSNL           Indoor           3G       3      Satisfactory
# 5-1-22      RJio          Outdoor           4G       4      Satisfactory
# 6-1-22      RJio          Outdoor           4G       4      Satisfactory
# 7-1-22      RJio          Outdoor           4G       4      Satisfactory
# 8-1-22      RJio           Indoor           4G       4      Satisfactory
# 9-1-22      RJio          Outdoor           4G       4      Satisfactory
# 10-1-22     RJio           Indoor           4G       4      Satisfactory
# 11-1-22     RJio           Indoor           4G       4      Satisfactory
# 13-1-22     RJio          Outdoor           4G       5      Satisfactory
# 14-1-22     RJio          Outdoor           4G       4      Satisfactory
# ...

# %% [markdown]
# Doing  a graph  visualization  of  satisfactory  feeds   from customer

# %%
sns .countplot(df['calldrop_category'])

# so  we  have less of call dropped 
# we  have  a medium poor voice  quality  calls
# and  we  have  a  highest  satisfactory  quality  calls
# Out:
# <AxesSubplot:xlabel='calldrop_category', ylabel='count'>

# %% [markdown]
# so  the  rate  of satisfactory  customer  is  the  maximum , according  the  Blue  bar

# %% [markdown]
# checking  the calldrop_category  vs  the network  rating

# %%
g = sns .catplot(x ='calldrop_category', y = 'rating',hue='operator',  data =df, kind='bar')
plt.show()

# %% [markdown]
# So  we can  easily  analyize   that
# Jio  has  the  highest  satisfactory  calls accroding  to  customer feeds
#   ,Bsnl and Vi have  same  level  of  satisfactory  customers  feeds.
#       ,airtel don't  have  a single satisfactory  feeds  from customer
#
# But addition  it  should be also added  that  airtel doesn't  have  any  poor voice  call  too., which  both Bsnl and Vi  has in them.
#
#
# And it is  to be noted  that  call drop is common  between all  the  operators  there

# %%
df
# Out:
#          operator inout_travelling network_type  rating   calldrop_category  \
# date
# 1-1-22       BSNL           Indoor           3G       3        Satisfactory
# 2-1-22       BSNL           Indoor           2G       3  Poor Voice Quality
# 3-1-22       BSNL           Indoor           2G       3        Satisfactory
# 4-1-22       BSNL           Indoor           3G       3        Satisfactory
# 5-1-22       RJio          Outdoor           4G       4        Satisfactory
# 6-1-22       RJio          Outdoor           4G       4        Satisfactory
# 7-1-22       RJio          Outdoor           4G       4        Satisfactory
# 8-1-22       RJio           Indoor           4G       4        Satisfactory
# 9-1-22       RJio          Outdoor           4G       4        Satisfactory
# 10-1-22      RJio           Indoor           4G       4        Satisfactory
# 11-1-22      RJio           Indoor           4G       4        Satisfactory
# ...

# %% [markdown]
# Rating Analysis

# %%
plt.violinplot(df['rating'])
plt.show()
#  here  the  rating   of  the  customer   is  show by  the  plot

# %% [markdown]
# so  from here  we  can analyze  that  1  rating  is  the maximum  rating  among   the , customers  and 5  rating  is minimum among   the  customers.
